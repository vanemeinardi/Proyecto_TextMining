# %%
import pandas as pd
import os
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import re

# %matplotlib inline

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 999)

# %%
directorio_actual = os.getcwd()
print("El directorio de trabajo actual es:", directorio_actual)
# Out:
# El directorio de trabajo actual es: g:\Unidades compartidas\Rocío doctorado\Proyecto NLP\Códigos

# %% [markdown]
# Leemos base de junio en formato csv y recreamos los tweets originales

# %%
datos_tweets_junio=pd.read_csv('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/tweets_junio_procesado.csv',  encoding='utf8')

# %%
datos_tweets_junio_latin=pd.read_csv('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/tweets_junio_procesado.csv',  encoding='latin1')

# %%
# # Filtrar tweets que no están cortados
datos_tweets_junio_latin = datos_tweets_junio_latin[~datos_tweets_junio_latin['full_text'].str.endswith('¦')]
# Obtener los índices de los tweets no cortados
indices_no_cortados = datos_tweets_junio_latin.index

# Filtrar otra tabla usando los índices de los tweets no cortados
datos_filtrados = datos_tweets_junio.loc[indices_no_cortados]

# %%
datos_filtrados.head(5)
# Out:
#     retweet_count  \
# 2               0
# 3               0
# 6               0
# 9               0
# 15              0
#
#                                                                                                                                                                                                                          full_text  \
# 2                                                                                                                                          En el fondo lo que les jode es nuestra libertad #NoVotenContraLasMujeres #AbortoLegalYA
# 3   holla! me gustaría q ayuden a esta junta d firmas para el aborto seguro y gratuito, gracias   Aprueben la Ley de Aborto Seguro y Gratuito @DiputadosAR #abortolegalya #13JAbortoLegal https://t.co/aT9bKgrh9P via @ChangeorgAR
# 6                                                                                                                                                                 Porque somos dueñas de nuestrxs cuerpas #NoVotenContraLasMujeres
# 9                                                       #NoVotenContraLasMujeres estoy tan a la mitad de tener un postura definida en este tema!!entiendo y comprendo a ambas partes,es muy triste e injusto para las dos partes!!
# 15                                                                                                                                         @MatiasRodrigTDF @LuzScarpati Que los @DiputadosAR  #NoVotenContraLasMujeres #QueSeaLey
#
#    posicion       user_name              user_id
# 2        si    Luz Scarpati           2999619141
# 3        si  gigi not hadid           3668114236
# 6        si   Malena Bianca             66200186
# 9        si         Cecilia  1005138863784976385
# 15       si     Elida Rechi           1475112482

# %%
datos_filtrados.to_csv('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/tweets_junio_recortados.csv', index=False)

# %%
df_tweets_junio=datos_filtrados
df_tweets_junio.shape
# Out:
# (392964, 5)

# %% [markdown]
# Limpiamos los textos de los tweets

# %%
# Descargar las stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('spanish'))  # Cambiar el idioma si es necesario

# Función para limpiar los tweets
def clean_tweet(tweet):
    tweet = re.sub(r'http\S+', '', tweet)  # Eliminar URLs
    tweet = re.sub(r'@\w+', '', tweet)  # Eliminar menciones de usuarios
    tweet = re.sub(r'#(\w+)', r'\1', tweet)  # Eliminar el '#' de los hashtags, dejando el texto
    #tweet = re.sub(r'#(\w+)', '', tweet)  # Eliminar el '#' de los hashtags, dejando el texto
    tweet = re.sub(r'[^\w\s]', '', tweet)  # Eliminar puntuación
    tweet = tweet.lower()  # Convertir a minúsculas
    tweet = re.sub(r'\brt\b', '', tweet, flags=re.IGNORECASE)  # Eliminar 'RT'
    tweet = ' '.join([word for word in tweet.split() if word not in stop_words])  # Eliminar stopwords
    return tweet

# Limpiar los tweets en la columna 'text'
df_tweets_junio['clean_text'] = df_tweets_junio['full_text'].apply(clean_tweet)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rocio\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_tweets_junio['clean_text']
# Out:
# 2                                                                                                 fondo jode libertad novotencontralasmujeres abortolegalya
# 3                holla gustaría q ayuden junta d firmas aborto seguro gratuito gracias aprueben ley aborto seguro gratuito abortolegalya 13jabortolegal via
# 6                                                                                                           dueñas nuestrxs cuerpas novotencontralasmujeres
# 9                                  novotencontralasmujeres tan mitad tener postura definida temaentiendo comprendo ambas parteses triste injusto dos partes
# 15                                                                                                                        novotencontralasmujeres quesealey
#                                                                                  ...
# 1041566                                                               ojalá médicos organicen marchen gritar cuenten vamos acompañar miles miles noalaborto
# 1041568                                                                                                                     argentinaesprovida quién senado
# 1041571    debe senil pobre avísenle blanco aparecer verde desaparecer salvemoslas2vidas noalaborto noalabortoenargentina nomatesatuhijo argentinaesprovida
# 1041574                                                                                              aranguren cabrera primeros abortados salvemoslas2vidas
# 1041580                                                                                              aranguren cabrera primeros abortados salvemoslas2vidas
# Name: clean_text, Length: 392964, dtype: object

# %% [markdown]
# Observamos que las posiciones 'si' y 'no' están desbalanceadas

# %%
df_tweets_junio['posicion'].value_counts()
# Out:
# posicion
# si    288761
# no    104203
# Name: count, dtype: int64

# %% [markdown]
# Realizamos un submuestreo de la clase mayoritaria

# %%
# Identificar la clase minoritaria y mayoritaria
conteo_clases = df_tweets_junio['posicion'].value_counts()
clase_minoritaria = conteo_clases.idxmin()  # Clase con menos instancias
clase_mayoritaria = conteo_clases.idxmax()  # Clase con más instancias

# Filtrar los DataFrames por clases
df_minoritaria = df_tweets_junio[df_tweets_junio['posicion'] == clase_minoritaria]
df_mayoritaria = df_tweets_junio[df_tweets_junio['posicion'] == clase_mayoritaria]

# Submuestreo de la clase mayoritaria
df_mayoritaria_submuestreada = df_mayoritaria.sample(len(df_minoritaria), random_state=42)

# Combinar los DataFrames
df_balanceado = pd.concat([df_mayoritaria_submuestreada, df_minoritaria])

# Barajar el DataFrame resultante
df_balanceado = df_balanceado.sample(frac=1, random_state=42).reset_index(drop=True)

# Mostrar el balance final de las clases
print(df_balanceado['posicion'].value_counts())
# Out:
# posicion
# no    104203
# si    104203
# Name: count, dtype: int64

# %% [markdown]
# Transformamos el texto en una representación numérica utilizando CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords

# Descargar stopwords en español
nltk.download('stopwords')
stop_words = list(stopwords.words('spanish'))  # Convertir el set a lista

# Vectorizar los tweets usando la lista de stopwords
vectorizer = CountVectorizer(max_df=0.99, min_df=10000, stop_words=stop_words)  # Usa la lista de stopwords
X = vectorizer.fit_transform(df_balanceado['clean_text'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rocio\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Configurar el número de tópicos (ajustar según el caso)
num_topics = 2

# Entrenar el modelo LDA
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
# Mostrar las palabras más importantes por tópico
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Tópico {topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# Mostrar los temas
no_top_words = 10
feature_names = vectorizer.get_feature_names_out()
display_topics(lda, feature_names, no_top_words)
# Out:
# Tópico 1:
# abortolegalya aborto noalaborto quesealey si abortosesionhistorica argentina favor mujeres abortolegal
# Tópico 2:
# argentinaesprovida salvemoslas2vidas vida noalabortoenargentina abortoseraley hoy abortolegal elijamoslas2vidas mujeres si

# %%
X_nuevo = vectorizer.transform(df_tweets_junio['clean_text'])

# %%
X_nuevo
# Out:
# <392964x17 sparse matrix of type '<class 'numpy.int64'>'
# 	with 636574 stored elements in Compressed Sparse Row format>

# %%
# Asignar el tópico más probable a cada tweet
topic_values = lda.transform(X_nuevo)
df_tweets_junio['topico'] = topic_values.argmax(axis=1)

# Ver los resultados
print(df_tweets_junio[['full_text', 'topico', 'posicion']].head())
# Out:
#                                                                                                                                                                                                                          full_text  \
# 2                                                                                                                                          En el fondo lo que les jode es nuestra libertad #NoVotenContraLasMujeres #AbortoLegalYA
# 3   holla! me gustaría q ayuden a esta junta d firmas para el aborto seguro y gratuito, gracias   Aprueben la Ley de Aborto Seguro y Gratuito @DiputadosAR #abortolegalya #13JAbortoLegal https://t.co/aT9bKgrh9P via @ChangeorgAR
# 6                                                                                                                                                                 Porque somos dueñas de nuestrxs cuerpas #NoVotenContraLasMujeres
# 9                                                       #NoVotenContraLasMujeres estoy tan a la mitad de tener un postura definida en este tema!!entiendo y comprendo a ambas partes,es muy triste e injusto para las dos partes!!
# 15                                                                                                                                         @MatiasRodrigTDF @LuzScarpati Que los @DiputadosAR  #NoVotenContraLasMujeres #QueSeaLey
#
#     topico posicion
# 2        0       si
# 3        0       si
# 6        0       si
# 9        0       si
# 15       0       si

# %%
tabla_porcentaje = pd.crosstab(df_tweets_junio['topico'], df_tweets_junio['posicion'], normalize='columns') * 100 

# Mostrar la tabla de contingencia con porcentajes
print(tabla_porcentaje)
# Out:
# posicion         no         si
# topico
# 0         19.946643  78.754056
# 1         80.053357  21.245944

# %%
df_tweets_junio.to_csv('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/tweets_junio_LDA.csv')

# %% [markdown]
# ## Selección de muestras para evaluación anecdótica

# %%
datos = pd.read_csv('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/tweets_junio_LDA.csv')

# %%
datos.columns
# Out:
# Index(['Unnamed: 0', 'retweet_count', 'full_text', 'posicion', 'user_name',
#        'user_id', 'clean_text', 'topico'],
#       dtype='object')

# %%
unicos_user_name=datos.drop_duplicates(['user_name'])
unicos_user_name['orden'] = range(len(unicos_user_name))
muestras = []

for nombre_topico, grupo in unicos_user_name.groupby('topico'):
    n_samples = min(40, len(grupo))
    
    if n_samples > 0:  # Asegurarse de que hay usuarios disponibles
        muestra = grupo.sample(n=n_samples, random_state=42, replace=False)
        muestras.append(muestra)

# Combinar todas las muestras en un DataFrame
muestra_topicos = pd.concat(muestras).reset_index(drop=True)

# Paso 4: Seleccionar solo las columnas 'user_name', 'full_text' y 'topico'
muestra_topicos = muestra_topicos[['user_name', 'full_text', 'topico']]

# Paso 5: Unir con el DataFrame original para recuperar el orden
muestra_topicos = muestra_topicos.merge(unicos_user_name[['user_name', 'orden']], on='user_name', how='left')

# Paso 6: Ordenar por la columna 'orden' y eliminar la columna 'orden'
muestra_topicos = muestra_topicos.sort_values(by='orden').drop(columns='orden')

# Paso 7: Agregar la columna 'Clasificacion' como vacía
muestra_topicos['Clasificacion'] = ''

# Paso 8: Reordenar las columnas para que 'comunidad' esté al principio
muestra_topicos = muestra_topicos[['topico', 'user_name', 'full_text', 'Clasificacion']]

# Supongamos que ya tienes tu DataFrame llamado muestra_comunidades
# muestra_topicos = muestra_topicos.sample(frac=1)

muestra_topicos
# Out:
# C:\Users\rocio\AppData\Local\Temp/ipykernel_6700/454498174.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unicos_user_name['orden'] = range(len(unicos_user_name))
#     topico                user_name  \
# 16       0                   paloma
# 49       1                Flor Wosh
# 28       0           Marcela Godoy💚
# 22       0                fiminizi🐢
# 41       1          Mujer❤Maravilla
# 39       0                    Iaru💜
# 31       0               Cristina .
# 61       1           Jenifer Correa
# 21       0                  sabro,,
# 8        0       Ariel Sebas Borgna
# 29       0                    T-Rex
# 35       0                 Shonatan
# 53       1     MARIA ELENA MARTINEZ
# 18       0     ღ Ximena Aschemacher
# 37       0            gloria mendez
# 4        0                    Enanö
# 24       0             Nina Flawlss
# 5        0        Cualquier Verdura
# 1        0                   sahara
# 25       0                  Nerea 💚
# 68       1                    Mili❌
# 42       1                 Julia✊🏻💚
# 43       1                Salomé ☯🛠
# 46       1       Alejandra Troncoso
# 71       1               Marcela C.
# 30       0                 Guidito🌊
# 26       0          Marcela Cerrudo
# 19       0             Nati Gouiric
# 10       0                     Paø💚
# 62       1                   Sofa 💚
# 76       1              Ana Sevilla
# 48       1             myrna alfaro
# 51       1  Colorada Yeta ✨💊🌰 -18🏰💫
# 47       1           elvis-is-alive
# 67       1         La Resistencia 💙
# 40       1        patricia alvarado
# 0        0               MARGINALES
# 58       1             Jonas devran
# 64       1                 Bodyyyy_
# 55       1              Adriana Mg.
# 72       1                l u c ì a
# 78       1                     ναl💙
# 45       1                   Mati 💙
# 57       1          ANTONIO CORONEL
# 74       1                     Fio🌸
# 73       1             Fachx Progrx
# 2        0     Lourdes Ledesma L.I.
# 79       1            nicolas rossi
# 60       1            Daniel Devesa
# 44       1             Dani Taborda
# 9        0        Alejandro Mariani
# 3        0                     Tam🎈
# 63       1         Ciruja abortista
# 75       1                 cholita💚
# 13       0      Crustáceo Cascarudo
# 17       0          Luli Beltramo 💚
# 20       0         Enric Salvador 🎗
# 34       0             tomas agrebu
# 6        0                     Lu 🦋
# 23       0                    Lilus
# 69       1        Sebastián Lacalle
# 54       1           Diego Lovegood
# 70       1                  santi ⑫
# 38       0                Ma(b)ruja
# 66       1            Adriana Meyer
# 11       0                     LEB🌛
# 56       1                       vs
# 32       0             Rocio Agüero
# 59       1                     -jj-
# 12       0           Maii errecart🐽
# 7        0                  Palermo
# 27       0                   kaneda
# 33       0        SOY UN CACAHUATE😎
# 14       0          Diego Navarrete
# 52       1                   Gabyta
# 36       0                  Mayte ♀
# 65       1                  𝓨𝓸𝓒𝓪𝓼𝓽𝓸
# 50       1                   bel💚🇺🇾
# 15       0                   Shey❤️
# 77       1              Bearana.nun
#
#                                                                                                                                                                                                                                                                        full_text  \
# 16                                                                                                                                                                                                           luchando juntas, siempre. ✊💚 #AbortoLegalYa https://t.co/MhelBZqQ0v
# 49                                                                                                                                                          RT @CandelariaBotto: Las ricas abortan, las pobres mueren.   #abortolegal es justicia social https://t.co/0iBKdZrIDl
# 28  Hoy una periodista @Radio10 Paraná dijo estar en contra del aborto legal narrando: "les introducen cosas peligrosas antinaturales" . Una periodista. Comunicadora. Dicen barbaridades con total normalidad. Sus palabras describian  un aborto clandestino. #AbortoLegalYa 💚
# 22                                                                                                                                                                                                                          4 días para la votación en diputados. #abortolegalya
# 41               @Florfreijo Hay la quien elije la vida, obligan a su hija 16 años a tener su hijo ...ya le tenía casa para que se junto con su marido , hoy 21 años con 2 hijos y parece de 30 años , como le paso la vida tan rápido a esa criatura ... por eso #abortolegalya
# 39                                                                                                                                  RT @delfi_benavidez: lo escribí yo, espero que no salgan a bardearme porque es simplemente mi opinión #AbortoLegalYA https://t.co/sNHpiLNing
# 31                                                                                                                                                                         RT @MaviiVidela: 💚JUNTOS PODEMOS💚 #AbortoLegalYa  #AbortoLegalSeguroYGratuito https://t.co/clHX8Vn1ao
# 61                                                                  Esas pendejas que están tomando él colegio por él #AbortoLegal cuantos años tiene ? 15? 16? 17? Xq no se ponen a estudiar y ser alguien en un futuro antes de andar haciendo marchas. #SiAlaVida #NoAlAborto
# 21                                                                                                                                                   RT @paulitachaves: Pueden entender que no es ABORTO SI O ABORTO NO.... es LEGAL o CLANDESTINO... es facil... #AbortoLegalYa
# 8                        ... el derecho es algo que va a permitir decidir sobre el propio destino de la vida. Gritamos, con la voz, con el cuerpo, con cada pañuelo verde: Educación Sexual para decidir Anticonceptivos para no abortar #AbortoLegalYa para no morir #QueSeaLey
# 29                                                                                                                                                     RT @murielsantaok: #AbortoLegalOClandestino #AbortoLegalYa @Aruzzireal hermosaaaaa! @actrices_arg https://t.co/DR9KU0Qnat
# 35                                                                                                                                                                                                        Va a ser ley 💚  #AbortoLegalYA #13JAbortoLegal https://t.co/JzAHqxfNGh
# 53                                                                                                                                           RT @gonzaloaziz: Ahora/ @DiputadosAR   HAY DICTAMEN DE MAYORÍA a favor del #AbortoLegal  Mañana, sesión a las 11 hs.  @todonoticias
# 18                                                                                                                                                           RT @tijereteando: Hoy hice este Gif abortero 💚💪🏻  Se los regalo ✨ #QueSeaLey #abortolegalya https://t.co/fO01BrQOsx
# 37                                                                                                                                                                                        RT @MartinZCaceres: Trabajo en hospital en Neuquen. No asesinaré a tu hijo #NoAlAborto
# 4                                                                                                                                                                                                               RT @Brisaxl_: Mañana. #QueElAbortoSeaLey https://t.co/ULwBWuv1C7
# 24                                                                                                                                                                                                   #QueElAbortoSeaLey para tener más educación, más desición y no más muertes.
# 5                                                                                                                                                                                                         RT @marinabutron: Nuestro Mundial 💚 #QueSeaLey https://t.co/aRTRedUplJ
# 1                                                                                                                                    RT @FonziDolores: Aprueben la Ley de Aborto Seguro y Gratuito #abortolegalya - ¡Firmá la petición! https://t.co/isunk8sUXP vía @ChangeorgAR
# 25                                                                                                                                                                                                             RT @NatiRamoneOk: Y sigue. #AbortoLegalYa https://t.co/FIfFpeX6Px
# 68                                                                                                                                                                                           RT @SoleVallejos: -¿qué queremos?  #niunamenos #abortolegal https://t.co/hQcyynEqrG
# 42                                                                                                                                                                                                    RT @vertacnikk: No todos saben esto👇🏻 #AbortoLegal https://t.co/htmgeZtLEF
# 43                                                                                                                                                                                                     RT @Iiamdemons: mmm vos decis #ArgentinaEsProvida https://t.co/i2qhwxfmi7
# 46                                                                                                                                                                                                RT @agustinjsmon: En Mendoza ahora #ArgentinaEsProvida https://t.co/Gua2HsDQp8
# 71                                                                                                                                                                            RT @AmelieGranata: Con Uma decimos: SI A LA VIDA #CuidemosLasDosVidas ❤️❤️ https://t.co/mGfDwWIIWO
# 30                                                                                                                                                                    RT @diaryoftini: piel de gallina  #QueSeaLey #AbortoLegalYa #AbortoSesionHistorica https://t.co/d3ogIl3x6T
# 26                                                                                                                                                                                     RT @eugtobaloficial: Yo voto por el derecho a decidir. #QueSeaLey https://t.co/UjMELMnl6B
# 19                                                                                                                                                                                           #QueSeaLey no quiere decir que sea obligatorio. El Estado debe legislar para todxs.
# 10                                                                                                                                                                                  RT @CaroFrangu: Tucumán explota de lucha feminista!!! #AbortoLegalYa https://t.co/styGdnekQG
# 62                                                                                                                                                                                                     RT @Iiamdemons: mmm vos decis #ArgentinaEsProvida https://t.co/i2qhwxfmi7
# 76                                                                                                                                       RT @mzasialavida: Ayer más de 75000 personas dijeron #SalvemosLas2Vidas  #ArgentinaesProvida  #Mendozaesprovida https://t.co/b3zqamHk6Z
# 48                                                                                                                                        RT @marianoobarrio: TUCUMAN, EL JARDIN DE LA VIDA!!! #ArgentinaesProvida Aflojen, me van a hacer emocionar.... https://t.co/C7hy4jKn4u
# 51                                                                                                                                             JAJAJAJAJAJAJAJAJAJAJJAJAJAJAJAJJAJJAJAJAJJAJAJAJAJJAJAJAJAJAJJAJAJAJAJAJAJAJAJA me rio mas o asi esta bien?  #ArgentinaEsProvida
# 47                                                                                                                                                                  RT @adolfo_mac: #ArgentinaEsProvida #SalvemosLas2Vidas Miles de personas en #Rosario https://t.co/jUdCaPdxGe
# 67                                                                                                                                                                  RT @adolfo_mac: #ArgentinaEsProvida #SalvemosLas2Vidas Miles de personas en #Rosario https://t.co/jUdCaPdxGe
# 40                                                                                                                                                                RT @MarchaVidaLima: #ArgentinaEsProVida Córdoba y Tucumán también defienden la vida🤰🏻🙌 https://t.co/XsYnWIQlXR
# 0                                                                                                                                                                       RT @Sofy_Breyaue: "Estar a favor del aborto no significa abortar" #AbortoLegalYa https://t.co/VPWw2aRLf4
# 58                                                                                                                                                                                                                                        #ElijamosLas2Vidas ... sin duda alguna
# 64                                                                                                                                                                               RT @hijuetigre: #ReDePorteño #SalvemosLas2Vidas Dujovne y Sturzenegger   A quien votas en 2019?
# 55                                                                                                                                       RT @GustavoBruzone: Esta cuenta apuesta a la vida y le dice NO al ABORTO.   #ElijamosLas2Vidas  #13JAbortoLegal https://t.co/NCChKHV8FV
# 72                                                                                                                                                                                  RT @carlitacoll: Quienes somos nosotros para decidir quien merece vivir?  #Elijamoslas2vidas
# 78                                                                                                                                                                                               RT @amanda_gerez: Flaca acepta que no todos piensas como vos #SalvemosLas2Vidas
# 45                                                                                                                                                         RT @Jeerososa: Abortar no es SOLUCIÓN. abortar es destrucción para ambos.  #Salvemoslas2Vidas  #NoAlAbortoEnArgentina
# 57                                                                                                                                  RT @vanev87: Paraguay dice SI a la VIDA!Apoyamos a Argentina en su lucha💪 #SalvemosLas2Vidas  #NoAlAbortoEnArgentina https://t.co/8w5VxEkfhu
# 74                                                                                                                                                                                                                          Hoy me da asco entrar a Twitter.  #SalvemosLas2Vidas
# 73                                                                                                                                                                      Lo que los medios no te muestran #SalvemosLas2Vidas  #LaVidaNoSeNegocia #ProVida https://t.co/NAZJv0qlp1
# 2                                                                                                                                                                                  Aborto legal? Tan Bajo Caiste Argentina? Con Ley O Sin Ley La Vida Va Primero!💙 #NoAlAborto.💙
# 79                                                                                                                                                                                           @telefe pone en la pantalla el tema del #Aborto  #TodoPorMiHija  #SalvemosLas2Vidas
# 60                                                                                                                                          RT @psurtubi: Cultura de la Vida              Vs  Cultura de la Muerte #SiALasDosVidas  #CuidemosLasDosVidas https://t.co/9FwkXeylis
# 44         Estaba de 6 semanas cuándo me enteré que estaba embarazada, de 15 cuándo sentí el primer cosquilleo y de 18 cuándo me enteré que era un VARÓN! De verdad me queres hacer creer que "NO siente nada el bebé"? VIVILO, EXPERIMENTALO Y SENTILO.  #NoAlAbortoEnArgentina
# 9                                                                                                                                                                                                                            @JohnPaulOk @Ailindlaiglesia #NoAlAborto perro 🤚🏻🤟🏻
# 3                                                                                                                                                                                   RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 63                                                                                                                                             RT @baronjimena: 💚 NOS TENEMOS MUJERES SUPERPODEROSAS💚 GRACIAS POR HACER HISTORIA JUNTAS 💚 #AbortoSeraLey https://t.co/TBeuqjkSGd
# 75                                                                                                                                             RT @baronjimena: 💚 NOS TENEMOS MUJERES SUPERPODEROSAS💚 GRACIAS POR HACER HISTORIA JUNTAS 💚 #AbortoSeraLey https://t.co/TBeuqjkSGd
# 13                                                                                                                                      RT @samnbk: Afuera de las calles cuando se anunció la votación. Qué pinche emoción. No puede ser. #AbortoLegalYa https://t.co/93kSXHwpKg
# 17                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 20                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 34                                                                                                                                  RT @CampAbortoLegal: ¿Queres saber qué diputadxs votaron en contra de nuestro derecho? 👇 Acá la lista #AbortoLegalYA https://t.co/nhcx0Kn3aC
# 6                                                                                                                                               RT @sweetiehstl: me paro y le aplaudo a esta mujer  #AbortoSesionHistorica #AbortoLegalYa #AbortoSeraLey https://t.co/8FewNEywQ0
# 23                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 69                                                                                                                                   RT @VictoriaAilenM: La diferencia es abismal. No pueden hacerse los que no lo ven. Sean responsables #AbortoSeraLey https://t.co/86IhyNqJ50
# 54                                                                                                                                                                                                                             Argentina se quedó sin ingenieros. #AbortoSeraLey
# 70                                                                                 #AbortoSeraLey gente falta media sanción de la cámara de senadores para aprobar o no la ley. no festejen ni se pongan tristes todavia. el sistema funciona asi desde hace un par de añitos...
# 38                                                                                                                                        RT @piquetuitera: Amo que el #AbortoLegalYa genere tanto consenso, es como ese tema que decía "bailan las rochas, también las chetas".
# 66           Histórica votación en Diputados: la marea verde consiguió media sanción para #AbortoLegal Imagen LID es la que más representa lo sucedido (pero no es media sanción sino sanción de Diputados) https://t.co/VpyBVUmeOW https://t.co/3G5kti0Vm2 vía @izquierdadiario
# 11                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 56                                                                                                                                       Creo que no comprendemos lo que realmente significa y representa esta media sanción. Es fascinante en muchos aspectos. 💚 #AbortoSeraLey
# 32                                                                                                                                                                                     Me encanta ver todas mis redes sociales color verde, que lindooo! #AbortoLegalYa #13J 💚✊💚
# 59                                                                                                                                                                   RT @ludeponti: Dormimos poco, soñamos mucho 🤗 Vamos las pibas! 💪🏼 #AbortoSeraLey 💚💜 https://t.co/Ne53OvVsNK
# 12                                                                                                                                                                                                     RT @juanittinelliok: Mañana💚 #AbortoLegalYa #AbortoLegalOClandestino #13J
# 7                                                                                                                                                                                   RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 27                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 33                                                                                                                                                    Hoy hacemos historia! #13JAbortoLegal #13JAbortoLegalYA #QueElAbortoSeaLey #AbortoSesionHistorica #AbortoLegalOClandestino
# 14                                                                                                                                                                                  RT @dmbatlle: Se gritó como un gol de Messi. Emoción. #AbortoLegalYa https://t.co/mRQD3iKfW3
# 52                                                                                                                                                                                                  RT @ludeponti: En serio no las ven?   #AbortoSeraLey https://t.co/3qBhssHzQP
# 36                                                                                                                                                   RT @lavrazz: Lo PERFECTO que habló Victoria Donda  #QueSeaLey #AbortoLegalYa #AbortoSesionHistorica https://t.co/Fcy5XFj9SG
# 65                                                                                                                                                                                          RT @teresita_ok: @YoCasto Gracias, tenemos que conseguir que el #AbortoLegal #SeaLey
# 50                                                                                                                                                                                                       RT @larremh: #AbortoLegal Uruguay: la historia. https://t.co/Uxca1CWeQv
# 15                                                                                                                                                                                RT @EstradaBet0: "La primera persona en reconocer a Jesús fue un niño sin nacer"   #NoAlAborto
# 77                                                                                                                                                                                       RT @FacundoLabay: Mendoza dice si a la vida #ArgentinaEsProVida https://t.co/5GbBzbEVP0
#
#    Clasificacion
# 16
# 49
# 28
# 22
# 41
# 39
# 31
# 61
# 21
# 8
# 29
# 35
# 53
# 18
# 37
# 4
# 24
# 5
# 1
# 25
# 68
# 42
# 43
# 46
# 71
# 30
# 26
# 19
# 10
# 62
# 76
# 48
# 51
# 47
# 67
# 40
# 0
# 58
# 64
# 55
# 72
# 78
# 45
# 57
# 74
# 73
# 2
# 79
# 60
# 44
# 9
# 3
# 63
# 75
# 13
# 17
# 20
# 34
# 6
# 23
# 69
# 54
# 70
# 38
# 66
# 11
# 56
# 32
# 59
# 12
# 7
# 27
# 33
# 14
# 52
# 36
# 65
# 50
# 15
# 77

# %%
# Exportar el DataFrame a un archivo Excel con dos hojas
with pd.ExcelWriter('g:/Unidades compartidas/Rocío doctorado/Proyecto NLP/Datos/muestras_topicos.xlsx') as writer:
    muestra_topicos.to_excel(writer, sheet_name='Vanesa', index=False)
    muestra_topicos.to_excel(writer, sheet_name='Rocio', index=False)

# El archivo 'muestras_topicos.xlsx' tendrá dos hojas: 'Vanesa' y 'Rocio'
